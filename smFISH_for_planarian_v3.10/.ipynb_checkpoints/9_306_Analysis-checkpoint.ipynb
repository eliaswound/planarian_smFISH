# %%
# Getting all assignment results in nucleiing 
import glob
import os
import numpy as np
def find_all_files (folder_path, file_name):
    # Define the folder to search in
    folder_path = path
    # Find all matching files
    matching_filenames = glob.glob(os.path.join(folder_path, '**', file_name), recursive=True)
    
    # Print the list of matching files
    for file in matching_filenames:
        print(file)
    return matching_filenames

# %%
path = "/Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/0hr_Amputation"
spot_in_nuclei = sorted(find_all_files (path, "concatenated_spot_in_nuclei.npy"))
Amputation_0h = []
for i in range(len(spot_in_nuclei)):
    
    cells = np.load(spot_in_nuclei[i])
    cells = cells[cells > 0]
    Amputation_0h.append(cells)
intensity_in_nuclei = sorted(find_all_files (path, "concatenated_intensity_in_nuclei.npy"))
Amputation_0h_intensity = []
for i in range(len(intensity_in_nuclei)):
    
    cells = np.load(intensity_in_nuclei[i])
    cells = cells[cells > 0]
    Amputation_0h_intensity.append(cells)
# Out:
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/0hr_Amputation/Image1/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/0hr_Amputation/Image1/565/results/concatenated_intensity_in_nuclei.npy

# %%
path = "/Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/0hr_Incision"
spot_in_nuclei = sorted(find_all_files (path, "concatenated_spot_in_nuclei.npy"))
Incision_0h = []
for i in range(len(spot_in_nuclei)):
    
    cells = np.load(spot_in_nuclei[i])
    cells = cells[cells > 0]
    Incision_0h.append(cells)
intensity_in_nuclei = sorted(find_all_files (path, "concatenated_intensity_in_nuclei.npy"))
Incision_0h_intensity = []
for i in range(len(intensity_in_nuclei)):
    
    cells = np.load(intensity_in_nuclei[i])
    cells = cells[cells > 0]
    Incision_0h_intensity.append(cells)
# Out:
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/0hr_Incision/Image1/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/0hr_Incision/Image2/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/0hr_Incision/Image3/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/0hr_Incision/Image1/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/0hr_Incision/Image2/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/0hr_Incision/Image3/565/results/concatenated_intensity_in_nuclei.npy

# %%
path = "/Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/6hr_Amputation"
spot_in_nuclei = sorted(find_all_files (path, "concatenated_spot_in_nuclei.npy"))
Amputation_6h = []
for i in range(len(spot_in_nuclei)):
    
    cells = np.load(spot_in_nuclei[i])
    cells = cells[cells > 0]
    Amputation_6h.append(cells)
intensity_in_nuclei = sorted(find_all_files (path, "concatenated_intensity_in_nuclei.npy"))
Amputation_6h_intensity = []
for i in range(len(intensity_in_nuclei)):
    
    cells = np.load(intensity_in_nuclei[i])
    cells = cells[cells > 0]
    Amputation_6h_intensity.append(cells)
# Out:
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/6hr_Amputation/Image2/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/6hr_Amputation/Image3/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/6hr_Amputation/Image1/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/6hr_Amputation/Image2/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/6hr_Amputation/Image3/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/6hr_Amputation/Image1/565/results/concatenated_intensity_in_nuclei.npy

# %%
path = "/Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/6hr_Incision"
spot_in_nuclei = sorted(find_all_files (path, "concatenated_spot_in_nuclei.npy"))
Incision_6h = []
for i in range(len(spot_in_nuclei)):
    
    cells = np.load(spot_in_nuclei[i])
    cells = cells[cells > 0]
    Incision_6h.append(cells)
intensity_in_nuclei = sorted(find_all_files (path, "concatenated_intensity_in_nuclei.npy"))
Incision_6h_intensity = []
for i in range(len(intensity_in_nuclei)):
    
    cells = np.load(intensity_in_nuclei[i])
    cells = cells[cells > 0]
    Incision_6h_intensity.append(cells)
# Out:
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/6hr_Incision/Image2/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/6hr_Incision/Image1/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/6hr_Incision/Image2/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/6hr_Incision/Image1/565/results/concatenated_intensity_in_nuclei.npy

# %%
path = "/Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Amputation/"
spot_in_nuclei = sorted(find_all_files (path, "concatenated_spot_in_nuclei.npy"))
Amputation_12h = []
for i in range(len(spot_in_nuclei)):
    
    cells = np.load(spot_in_nuclei[i])
    cells = cells[cells > 0]
    Amputation_12h.append(cells)
intensity_in_nuclei = sorted(find_all_files (path, "concatenated_intensity_in_nuclei.npy"))
Amputation_12h_intensity = []
for i in range(len(intensity_in_nuclei)):
    
    cells = np.load(intensity_in_nuclei[i])
    cells = cells[cells > 0]
    Amputation_12h_intensity.append(cells)
# Out:
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Amputation/Image2/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Amputation/Image3/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Amputation/Image1/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Amputation/Image2/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Amputation/Image3/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Amputation/Image1/565/results/concatenated_intensity_in_nuclei.npy

# %%
path = "/Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Incision"
spot_in_nuclei = sorted(find_all_files (path, "concatenated_spot_in_nuclei.npy"))
Incision_12h = []
for i in range(len(spot_in_nuclei)):
    
    cells = np.load(spot_in_nuclei[i])
    cells = cells[cells > 0]
    Incision_12h.append(cells)
intensity_in_nuclei = sorted(find_all_files (path, "concatenated_intensity_in_nuclei.npy"))
Incision_12h_intensity = []
for i in range(len(intensity_in_nuclei)):
    
    cells = np.load(intensity_in_nuclei[i])
    cells = cells[cells > 0]
    Incision_12h_intensity.append(cells)
# Out:
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Incision/Image1/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Incision/Image2/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Incision/Image3/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Incision/Image1/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Incision/Image2/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/12hr_Incision/Image3/565/results/concatenated_intensity_in_nuclei.npy

# %%
os.chdir("/Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment")
data_dict = {
    "Incision_0h": Incision_0h_intensity,
    "Amputation_0h": Amputation_0h_intensity,
    "Incision_6h": Incision_6h_intensity,
    "Amputation_6h": Amputation_6h_intensity,
    "Incision_12h": Incision_12h_intensity,
    "Amputation_12h": Amputation_12h_intensity
}
import pandas as pd
# Create a dictionary to store columns
csv_data = {}

# Iterate over each condition and store separately
for key, arrays in data_dict.items():
    for i, arr in enumerate(arrays, start=1):
        csv_data[f"{key}_{i}"] = arr  # Unique column name

# Convert to DataFrame
df = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in csv_data.items()]))

# Save to CSV
df.to_csv("314_output_intensity.csv", index=False)

print("CSV file saved as output.csv!")
# Out:
# CSV file saved as output.csv!

# %%
os.chdir("/Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment")
data_dict = {
    "Incision_0h": Incision_0h,
    "Amputation_0h": Amputation_0h,
    "Incision_6h": Incision_6h,
    "Amputation_6h": Amputation_6h,
    "Incision_12h": Incision_12h,
    "Amputation_12h": Amputation_12h
}

# Create a dictionary to store columns
csv_data = {}

# Iterate over each condition and store separately
for key, arrays in data_dict.items():
    for i, arr in enumerate(arrays, start=1):
        csv_data[f"{key}_{i}"] = arr  # Unique column name

# Convert to DataFrame
df = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in csv_data.items()]))

# Save to CSV
df.to_csv("314_output.csv", index=False)

print("CSV file saved as output.csv!")
# Out:
# CSV file saved as output.csv!

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
os.chdir("/Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment")
# Read the CSV file
df = pd.read_csv("314_output.csv")

# Convert to long format for seaborn
df_long = df.melt(var_name="Condition", value_name="Value")

palette = {
    'Incision_0h_1': 'green',
    'Incision_0h_2': 'green',
    'Incision_0h_3': 'green',
    'Amputation_0h_1': 'blue',
    'Amputation_0h_2': 'blue',
    'Amputation_0h_3': 'blue',
    'Incision_6h_1': 'green',
    'Incision_6h_3': "green",
    'Incision_6h_2': "green",
    'Amputation_6h_1': 'blue',
    'Amputation_6h_2': 'blue',
    'Amputation_6h_3': 'blue',
    'Incision_12h_1': 'green',
    'Amputation_12h_1': 'blue',
    'Amputation_12h_2': 'blue',
    'Amputation_12h_3': 'blue',
    'Incision_12h_2': 'green',
    'Incision_12h_3': 'green',
    'Amputation_12h': 'blue', 
    'Amputation_6h' :'blue',
    'Incision_12h' :'green',
    'Incision_6h' :'green',
    'Incision_0h' :'blue',
    'Amputation_0h':'blue'
}
df_long['Group'] = df_long['Condition'].str.extract(r'([A-Za-z]+_\d+h)')[0]



plt.figure(figsize=(12, 6))

# Boxplot without grouping (keep individual conditions)
sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, palette=palette)

# Jittered points with transparency and custom colors for each condition
sns.stripplot(x="Condition", y="Value", data=df_long, jitter=0.3, size=2, alpha=0.4, 
              hue="Condition", palette=palette, dodge=False, marker="o")

# Custom X-axis labels (show broader group names)
labels = df_long['Condition'].unique()# Get unique group names
plt.xticks(ticks=range(len(df_long['Condition'].unique())), labels=labels, rotation=30)

# Adjustments
plt.title("Jittered Box Plot of notum mRNA count in nuclei")
plt.ylabel("Count per cell")
plt.ylim(0,150)
plt.savefig("jittered_box_plot_of_mRNA_count_per_cell", dpi=300)
# Show the plot
plt.show()
# Out:
# /var/folders/s2/hm4xyqwd26xgwmf3znp5sffr0000gn/T/ipykernel_44000/2295653421.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, palette=palette)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
os.chdir("/Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment")
# Read the CSV file
df = pd.read_csv("314_output.csv")

# Convert to long format for seaborn
df_long = df.melt(var_name="Condition", value_name="Value")

palette = {
    'Incision_0h_1': 'green',
    'Incision_0h_2': 'green',
    'Incision_0h_3': 'green',
    'Amputation_0h_1': 'blue',
    'Amputation_0h_2': 'blue',
    'Amputation_0h_3': 'blue',
    'Incision_6h_1': 'green',
    'Incision_6h_3': "green",
    'Incision_6h_2': "green",
    'Amputation_6h_1': 'blue',
    'Amputation_6h_2': 'blue',
    'Amputation_6h_3': 'blue',
    'Incision_12h_1': 'green',
    'Amputation_12h_1': 'blue',
    'Amputation_12h_2': 'blue',
    'Amputation_12h_3': 'blue',
    'Incision_12h_2': 'green',
    'Incision_12h_3': 'green',
    'Amputation_12h': 'blue', 
    'Amputation_6h' :'blue',
    'Incision_12h' :'green',
    'Incision_6h' :'green',
    'Incision_0h' :'blue',
    'Amputation_0h':'blue'
}
df_long['Group'] = df_long['Condition'].str.extract(r'([A-Za-z]+_\d+h)')[0]



plt.figure(figsize=(12, 6))

# Boxplot without grouping (keep individual conditions)
sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, palette=palette)

# Violin plot (distribution)
sns.violinplot(
    x="Condition",
    y="Value",
    data=df_long,
    palette=palette,
    hue=None,
    dodge=False,
    cut=0,
    inner=None
)
sns.stripplot(
    x="Condition",
    y="Value",
    data=df_long,
    jitter=0.3,
    size=2,
    alpha=0.4,
    color="k",  # or use `palette=palette` and `hue="Condition"` if you want colored dots
    dodge=False
)
# Custom X-axis labels (show broader group names)
labels = df_long['Condition'].unique()
plt.xticks(ticks=range(len(labels)), labels=labels, rotation=30)

# Set log2 scale for Y-axis
plt.yscale("log", base=2)

# Adjustments
plt.title("Violin + Box Plot of notum mRNA count in nuclei (log2 scale)")
plt.ylabel("Log2(mRNA expression per cell)")
plt.savefig("violin_boxplot_of_mRNA_count_per_cell.png", dpi=300)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/s2/hm4xyqwd26xgwmf3znp5sffr0000gn/T/ipykernel_44000/1821544077.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, palette=palette)
# /var/folders/s2/hm4xyqwd26xgwmf3znp5sffr0000gn/T/ipykernel_44000/1821544077.py:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %%
from scipy.stats import ks_2samp
import pandas as pd

# KS test helper
def ks_test_by_condition(df, cond1, cond2):
    group1 = df[df["Condition"].str.startswith(cond1)]["Value"].dropna()
    group2 = df[df["Condition"].str.startswith(cond2)]["Value"].dropna()
    
    if len(group1) == 0 or len(group2) == 0:
        print(f"⚠️ One or both groups are empty: {cond1} vs {cond2}")
        return None
    
    stat, p_value = ks_2samp(group1, group2)
    print(f"{cond1} vs {cond2} --> KS stat: {stat:.4f}, p-value: {p_value:.4e}")
    return stat, p_value

# All desired comparisons
comparisons = [
    ("Incision_12h", "Amputation_12h"),
    ("Incision_0h", "Amputation_0h"),
    ("Amputation_12h", "Incision_6h"),
    ("Incision_12h", "Incision_6h"),
    ("Incision_6h", "Amputation_6h")  # New comparison
]

# Run and collect results
results = []
for cond1, cond2 in comparisons:
    result = ks_test_by_condition(df_long, cond1, cond2)
    if result:
        stat, pval = result
        results.append({
            "Comparison": f"{cond1} vs {cond2}",
            "KS_stat": stat,
            "p_value": pval
        })

# Convert to DataFrame and sort by p-value
results_df = pd.DataFrame(results).sort_values(by="p_value")
print("\n🧪 Sorted KS Test Results (by p-value):")
print(results_df.to_string(index=False))
results_df.to_csv("/Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment/ks_test_results.csv", index=False)
# Out:
# Incision_12h vs Amputation_12h --> KS stat: 0.2353, p-value: 8.7327e-70
# Incision_0h vs Amputation_0h --> KS stat: 0.0670, p-value: 8.0840e-02
# Amputation_12h vs Incision_6h --> KS stat: 0.3623, p-value: 4.5574e-147
# Incision_12h vs Incision_6h --> KS stat: 0.1352, p-value: 5.3824e-15
# Incision_6h vs Amputation_6h --> KS stat: 0.1076, p-value: 9.9101e-10
#
# 🧪 Sorted KS Test Results (by p-value):
#                     Comparison  KS_stat       p_value
#  Amputation_12h vs Incision_6h 0.362277 4.557408e-147
# Incision_12h vs Amputation_12h 0.235322  8.732653e-70
#    Incision_12h vs Incision_6h 0.135179  5.382364e-15
#   Incision_6h vs Amputation_6h 0.107569  9.910107e-10
#   Incision_0h vs Amputation_0h 0.067008  8.083952e-02

# %%
from scipy.stats import mannwhitneyu
def mann_whitney_by_condition(df, cond1, cond2, alternative="two-sided"):
    group1 = df[df["Condition"].str.startswith(cond1)]["Value"].dropna()
    group2 = df[df["Condition"].str.startswith(cond2)]["Value"].dropna()
    
    if len(group1) == 0 or len(group2) == 0:
        print(f"⚠️ One or both groups are empty: {cond1} vs {cond2}")
        return None
    
    stat, p_value = mannwhitneyu(group1, group2, alternative=alternative)
    print(f"{cond1} vs {cond2} --> U stat: {stat:.4f}, p-value: {p_value:.4e}")
    return stat, p_value
comparisons = [
    ("Incision_12h", "Amputation_12h"),
    ("Incision_0h", "Amputation_0h"),
    ("Amputation_6h", "Amputation_12h"),
    ("Incision_6h", "Incision_12h"),
    ("Incision_6h", "Amputation_6h")  # Added one
]

# Store results
mw_results = []
for cond1, cond2 in comparisons:
    result = mann_whitney_by_condition(df_long, cond1, cond2, alternative="less")
    if result:
        stat, pval = result
        mw_results.append({
            "Comparison": f"{cond1} vs {cond2}",
            "U_stat": stat,
            "p_value": pval
        })

# Create DataFrame and sort
mw_results_df = pd.DataFrame(mw_results).sort_values(by="p_value")
print("\n📊 Mann–Whitney U Test Results (sorted by p-value):")
print(mw_results_df.to_string(index=False))
mw_results_df.to_csv("mann_whitney_results.csv", index=False)
# Out:
# Incision_12h vs Amputation_12h --> U stat: 4063181.0000, p-value: 3.5291e-35
# Incision_0h vs Amputation_0h --> U stat: 250804.0000, p-value: 5.4560e-01
# Amputation_6h vs Amputation_12h --> U stat: 3874959.5000, p-value: 2.8508e-58
# Incision_6h vs Incision_12h --> U stat: 1291491.5000, p-value: 9.4144e-40
# Incision_6h vs Amputation_6h --> U stat: 1418132.0000, p-value: 1.2498e-23
#
# 📊 Mann–Whitney U Test Results (sorted by p-value):
#                      Comparison    U_stat      p_value
# Amputation_6h vs Amputation_12h 3874959.5 2.850833e-58
#     Incision_6h vs Incision_12h 1291491.5 9.414379e-40
#  Incision_12h vs Amputation_12h 4063181.0 3.529137e-35
#    Incision_6h vs Amputation_6h 1418132.0 1.249757e-23
#    Incision_0h vs Amputation_0h  250804.0 5.455977e-01

# %%
import pandas as pd
from scipy import stats

# Load the Excel file
file_path = "/Volumes/Backup Plus/Experiment_results/314_analysis_results/Injury_site_length_analysis_314.xlsx"
df = pd.read_excel(file_path)

# Merge data for each time point
incision_0hr = np.concatenate(Incision_0h)
amputation_0hr = np.concatenate(Amputation_0h)

incision_6hr = np.concatenate(Incision_6h)
amputation_6hr = np.concatenate(Amputation_6h)

incision_12hr = np.concatenate(Incision_12h)
amputation_12hr = np.concatenate(Amputation_12h)

# Perform independent t-tests
t_stat_0hr, p_value_0hr = stats.ttest_ind(incision_0hr, amputation_0hr, equal_var=False)
t_stat_6hr, p_value_6hr = stats.ttest_ind(incision_6hr, amputation_6hr, equal_var=False)
t_stat_12hr, p_value_12hr = stats.ttest_ind(incision_12hr, amputation_12hr, equal_var=False)
t_stat_6to12hrin, p_value_6to12hrin = stats.ttest_ind(incision_6hr, incision_12hr, equal_var=False)
t_stat_6to12hram, p_value_6to12hram = stats.ttest_ind(amputation_6hr, amputation_12hr, equal_var=False)
alpha = 0.05
print("\nStatistical Significance:")
print("0hr:", "Significant difference" if p_value_0hr < alpha else "No significant difference")
print(p_value_0hr)
print("6hr:", "Significant difference" if p_value_6hr < alpha else "No significant difference")
print(p_value_6hr)
print("12hr:", "Significant difference" if p_value_12hr < alpha else "No significant difference")
print(p_value_12hr)
print("12hrto6hrin", "Significant difference" if p_value_6to12hrin < alpha else "No significant difference")
print(p_value_6to12hrin)
print("12hrto6hram", "Significant difference" if p_value_6to12hram < alpha else "No significant difference")
print(p_value_6to12hram)
# Out:
# Statistical Significance:
# 0hr: No significant difference
# 0.13227675648770923
# 6hr: Significant difference
# 7.235910200532895e-08
# 12hr: Significant difference
# 3.0998161239861493e-21
# 12hrto6hrin Significant difference
# 3.826268242680319e-15
# 12hrto6hram Significant difference
# 1.0158544669846459e-79

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
os.chdir("/Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment")
# Read the CSV file
df = pd.read_csv("314_output_intensity.csv")

# Convert to long format for seaborn
df_long = df.melt(var_name="Condition", value_name="Value")

palette = {
    'Incision_0h_1': 'green',
    'Incision_0h_2': 'green',
    'Incision_0h_3': 'green',
    'Amputation_0h_1': 'blue',
    'Amputation_0h_2': 'blue',
    'Amputation_0h_3': 'blue',
    'Incision_6h_1': 'green',
    'Incision_6h_3': "green",
    'Incision_6h_2': "green",
    'Amputation_6h_1': 'blue',
    'Amputation_6h_2': 'blue',
    'Amputation_6h_3': 'blue',
    'Incision_12h_1': 'green',
    'Amputation_12h_1': 'blue',
    'Amputation_12h_2': 'blue',
    'Amputation_12h_3': 'blue',
    'Incision_12h_2': 'green',
    'Incision_12h_3': 'green',
    'Amputation_12h': 'blue', 
    'Amputation_6h' :'blue',
    'Incision_12h' :'green',
    'Incision_6h' :'green',
    'Incision_0h' :'blue',
    'Amputation_0h':'blue'
}
df_long['Group'] = df_long['Condition'].str.extract(r'([A-Za-z]+_\d+h)')[0]



plt.figure(figsize=(12, 6))

# Boxplot without grouping (keep individual conditions)
sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, palette=palette)

# Jittered points with transparency and custom colors for each condition
sns.stripplot(x="Condition", y="Value", data=df_long, jitter=0.3, size=2, alpha=0.4, 
              hue="Condition", palette=palette, dodge=False, marker="o")

# Custom X-axis labels (show broader group names)
labels = df_long['Condition'].unique()# Get unique group names
plt.xticks(ticks=range(len(df_long['Condition'].unique())), labels=labels, rotation=45)

# Adjustments
plt.title("Jittered Box Plot of notum mRNA intensity in nuclei")
plt.ylabel("Intensity(A.U). per nuclei")
plt.savefig("violin_boxplot_of_mRNA_intensity_per_cell.png", dpi=300)
# Show the plot
plt.show()
# Out:
# /var/folders/s2/hm4xyqwd26xgwmf3znp5sffr0000gn/T/ipykernel_44000/3557207049.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, palette=palette)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Set working directory
os.chdir("/Volumes/Backup Plus/Experiment_results/314_analysis_results/Experiment")

# Read the CSV file
df = pd.read_csv("314_output_intensity.csv")

# Convert to long format for seaborn
df_long = df.melt(var_name="Condition", value_name="Value")

# Color palette
palette = {
    'Incision_0h_1': 'green',
    'Incision_0h_2': 'green',
    'Incision_0h_3': 'green',
    'Amputation_0h_1': 'blue',
    'Amputation_0h_2': 'blue',
    'Amputation_0h_3': 'blue',
    'Incision_6h_1': 'green',
    'Incision_6h_2': 'green',
    'Incision_6h_3': 'green',
    'Amputation_6h_1': 'blue',
    'Amputation_6h_2': 'blue',
    'Amputation_6h_3': 'blue',
    'Incision_12h_1': 'green',
    'Incision_12h_2': 'green',
    'Incision_12h_3': 'green',
    'Amputation_12h_1': 'blue',
    'Amputation_12h_2': 'blue',
    'Amputation_12h_3': 'blue',
    'Amputation_12h': 'blue',
    'Amputation_6h': 'blue',
    'Incision_12h': 'green',
    'Incision_6h': 'green',
    'Incision_0h': 'blue',
    'Amputation_0h': 'blue'
}

# Extract group info
df_long['Group'] = df_long['Condition'].str.extract(r'([A-Za-z]+_\d+h)')[0]

# Plot setup
plt.figure(figsize=(14, 6))

# Violin plot (smoothed distribution)
sns.violinplot(x="Condition", y="Value", data=df_long, palette=palette,
               inner=None, cut=0)

# Boxplot on top
sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, 
            palette=palette, linewidth=1, width=0.3)

# Jittered individual data points
sns.stripplot(x="Condition", y="Value", data=df_long, jitter=0.3, size=2, 
              alpha=0.4, hue="Condition", palette=palette, dodge=False, marker="o")

# X-axis labels
labels = df_long['Condition'].unique()
plt.xticks(ticks=range(len(labels)), labels=labels, rotation=45)

# Log10 Y-axis scale
plt.yscale("log", base=10)
plt.ylabel("Log10(Intensity [A.U.] per nucleus)")

# Title and layout
plt.title("Violin + Box Plot of notum mRNA intensity in nuclei (log10 scale)")
plt.tight_layout()

# Save the figure
plt.savefig("violin_boxplot_of_mRNA_intensity_per_cell_log10.png", dpi=300)

# Show the plot
plt.show()
# Out:
# /var/folders/s2/hm4xyqwd26xgwmf3znp5sffr0000gn/T/ipykernel_44000/2986401667.py:50: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Condition", y="Value", data=df_long, palette=palette,
# /var/folders/s2/hm4xyqwd26xgwmf3znp5sffr0000gn/T/ipykernel_44000/2986401667.py:54: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False,

# %%
df_long = df.melt(var_name="Condition", value_name="Value")
df_long['Group'] = df_long['Condition'].str.extract(r'([A-Za-z]+_\d+h)')[0]
from scipy.stats import ks_2samp, mannwhitneyu

def ks_test_by_condition(df, cond1, cond2):
    group1 = df[df["Condition"].str.startswith(cond1)]["Value"].dropna()
    group2 = df[df["Condition"].str.startswith(cond2)]["Value"].dropna()
    if group1.empty or group2.empty:
        print(f"⚠️ Empty group for KS: {cond1} vs {cond2}")
        return None
    stat, p_value = ks_2samp(group1, group2)
    print(f"KS: {cond1} vs {cond2} → stat: {stat:.4f}, p: {p_value:.4e}")
    return {"Comparison": f"{cond1} vs {cond2}", "KS_stat": stat, "p_value": p_value}

def mann_whitney_by_condition(df, cond1, cond2, alternative="two-sided"):
    group1 = df[df["Condition"].str.startswith(cond1)]["Value"].dropna()
    group2 = df[df["Condition"].str.startswith(cond2)]["Value"].dropna()
    if group1.empty or group2.empty:
        print(f"⚠️ Empty group for MW: {cond1} vs {cond2}")
        return None
    stat, p_value = mannwhitneyu(group1, group2, alternative=alternative)
    print(f"MWU ({alternative}): {cond1} vs {cond2} → U: {stat:.4f}, p: {p_value:.4e}")
    return {"Comparison": f"{cond1} vs {cond2}", "U_stat": stat, "p_value": p_value}
comparisons = [
    ("Incision_12h", "Amputation_12h"),
    ("Incision_0h", "Amputation_0h"),
    ("Amputation_6h", "Amputation_12h"),
    ("Incision_6h", "Incision_12h"),
    ("Incision_6h", "Amputation_6h")]  # Added one

# Collect results
ks_results = []
mw_results = []

for c1, c2 in comparisons:
    ks = ks_test_by_condition(df_long, c1, c2)
    mw = mann_whitney_by_condition(df_long, c1, c2, alternative="two-sided")
    if ks: ks_results.append(ks)
    if mw: mw_results.append(mw)

# Convert to DataFrames
ks_df = pd.DataFrame(ks_results).sort_values("p_value")
mw_df = pd.DataFrame(mw_results).sort_values("p_value")

# Save results
ks_df.to_csv("ks_test_results_on_intensity.csv", index=False)
mw_df.to_csv("mannwhitneyu_results_on_intensity.csv", index=False)
# Out:
# KS: Incision_12h vs Amputation_12h → stat: 0.2353, p: 8.7327e-70
# MWU (two-sided): Incision_12h vs Amputation_12h → U: 3460222.5000, p: 6.2942e-88
# KS: Incision_0h vs Amputation_0h → stat: 0.0670, p: 8.0840e-02
# MWU (two-sided): Incision_0h vs Amputation_0h → U: 240192.5000, p: 1.9742e-01
# KS: Amputation_6h vs Amputation_12h → stat: 0.2656, p: 2.9780e-90
# MWU (two-sided): Amputation_6h vs Amputation_12h → U: 3162031.5000, p: 2.0412e-135
# KS: Incision_6h vs Incision_12h → stat: 0.1352, p: 5.3824e-15
# MWU (two-sided): Incision_6h vs Incision_12h → U: 1384183.0000, p: 6.6816e-20
# KS: Incision_6h vs Amputation_6h → stat: 0.1076, p: 9.9101e-10
# MWU (two-sided): Incision_6h vs Amputation_6h → U: 1573707.0000, p: 2.9321e-05

# %%
import pandas as pd
os.chdir("/Volumes/Backup Plus/Experiment_results/314_analysis_results")
# Load the Excel file
file_path = "Injury_site_length_analysis_314.xlsx"
df = pd.read_excel(file_path)

# Display the dataframe
print(df)
# Out:
#   Unnamed: 0  0h_Amputation  0h_Incision  6h_Amputation  6h_Incision  \
# 0     Image1        575.145      366.728        739.554      382.210
# 1     Image2            NaN      428.435        819.730      291.694
# 2     Image3            NaN      500.418        600.789          NaN
#
#    12h_Amputation  12h_Incision
# 0         926.973       308.338
# 1         831.856       265.736
# 2         837.430       418.455

# %%
def compute_sums(data_arrays, first_value):
    return [arr.sum() / first_value for arr in data_arrays]

# Function to compute lengths divided by first number in dataframe
def compute_lengths(data_arrays, first_value):
    return [len(arr) / first_value for arr in data_arrays]

# Create new DataFrames
sum_df = pd.DataFrame({
    "Incision_0h": compute_sums(Incision_0h, df["0h_Incision"][0]),
    "Amputation_0h": compute_sums(Amputation_0h, df["0h_Amputation"][0]),
    "Incision_6h": compute_sums(Incision_6h, df["6h_Incision"][0]),
    "Amputation_6h": compute_sums(Amputation_6h, df["6h_Amputation"][0]),
    "Incision_12h": compute_sums(Incision_12h, df["12h_Incision"][0]),
    "Amputation_12h": compute_sums(Amputation_12h, df["12h_Amputation"][0])
})

length_df = pd.DataFrame({
    "Incision_0h": compute_lengths(Incision_0h, df["0h_Incision"][0]),
    "Amputation_0h": compute_lengths(Amputation_0h, df["0h_Amputation"][0]),
    "Incision_6h": compute_lengths(Incision_6h, df["6h_Incision"][0]),
    "Amputation_6h": compute_lengths(Amputation_6h, df["6h_Amputation"][0]),
    "Incision_12h": compute_lengths(Incision_12h, df["12h_Incision"][0]),
    "Amputation_12h": compute_lengths(Amputation_12h, df["12h_Amputation"][0])
})

# Display results
print("Average spot count per injury site length DataFrame:")
print(sum_df)
sum_df.to_csv("314_output_spot_count_per_injuyr_site_length.csv", index=False)

print("CSV file saved as output.csv!")
print("\nAverage cell expressing per injury site length:")
print(length_df)
length_df.to_csv("314_output_Cell_expressing_per_injury_length.csv", index=False)

print("CSV file saved as output.csv!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 9
#       6     return [len(arr) / first_value for arr in data_arrays]
#       8 # Create new DataFrames
# ----> 9 sum_df = pd.DataFrame({
#      10     "Incision_0h": compute_sums(Incision_0h, df["0h_Incision"][0]),
#      11     "Amputation_0h": compute_sums(Amputation_0h, df["0h_Amputation"][0]),
#      12     "Incision_6h": compute_sums(Incision_6h, df["6h_Incision"][0]),
#      13     "Amputation_6h": compute_sums(Amputation_6h, df["6h_Amputation"][0]),
#      14     "Incision_12h": compute_sums(Incision_12h, df["12h_Incision"][0]),
#      15     "Amputation_12h": compute_sums(Amputation_12h, df["12h_Amputation"][0])
#      16 })
#      18 length_df = pd.DataFrame({
#      19     "Incision_0h": compute_lengths(Incision_0h, df["0h_Incision"][0]),
#      20     "Amputation_0h": compute_lengths(Amputation_0h, df["0h_Amputation"][0]),
#    (...)
#      24     "Amputation_12h": compute_lengths(Amputation_12h, df["12h_Amputation"][0])
#      25 })
#      27 # Display results
#
# File ~/anaconda3/envs/stardist-env/lib/python3.10/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File ~/anaconda3/envs/stardist-env/lib/python3.10/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/anaconda3/envs/stardist-env/lib/python3.10/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~/anaconda3/envs/stardist-env/lib/python3.10/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length
