# %%
# Getting all assignment results in nucleiing 
import glob
import os
import numpy as np
def find_all_files (folder_path, file_name):
    # Define the folder to search in
    folder_path = path
    # Find all matching files
    matching_filenames = glob.glob(os.path.join(folder_path, '**', file_name), recursive=True)
    
    # Print the list of matching files
    for file in matching_filenames:
        print(file)
    return matching_filenames

# %%
path = "/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Amputation"
spot_in_nuclei = sorted(find_all_files (path, "concatenated_spot_in_nuclei.npy"))
Amputation_0h = []
for i in range(len(spot_in_nuclei)):
    
    cells = np.load(spot_in_nuclei[i])
    cells = cells[cells > 0]
    Amputation_0h.append(cells)
intensity_in_nuclei = sorted(find_all_files (path, "concatenated_intensity_in_nuclei.npy"))
Amputation_0h_intensity = []
for i in range(len(intensity_in_nuclei)):
    
    cells = np.load(intensity_in_nuclei[i])
    cells = cells[cells > 0]
    Amputation_0h_intensity.append(cells)
# Out:
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Amputation/Image1/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Amputation/Image2/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Amputation/Image3/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Amputation/Image1/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Amputation/Image2/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Amputation/Image3/565/results/concatenated_intensity_in_nuclei.npy

# %%
path = "/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Incision"
spot_in_nuclei = sorted(find_all_files (path, "concatenated_spot_in_nuclei.npy"))
Incision_0h = []
for i in range(len(spot_in_nuclei)):
    
    cells = np.load(spot_in_nuclei[i])
    cells = cells[cells > 0]
    Incision_0h.append(cells)
intensity_in_nuclei = sorted(find_all_files (path, "concatenated_intensity_in_nuclei.npy"))
Incision_0h_intensity = []
for i in range(len(intensity_in_nuclei)):
    
    cells = np.load(intensity_in_nuclei[i])
    cells = cells[cells > 0]
    Incision_0h_intensity.append(cells)
# Out:
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Incision/Image1/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Incision/Image2/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Incision/Image3/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Incision/Image1/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Incision/Image2/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/0hr_Incision/Image3/565/results/concatenated_intensity_in_nuclei.npy

# %%
path = "/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Amputation"
spot_in_nuclei = sorted(find_all_files (path, "concatenated_spot_in_nuclei.npy"))
Amputation_6h = []
for i in range(len(spot_in_nuclei)):
    
    cells = np.load(spot_in_nuclei[i])
    cells = cells[cells > 0]
    Amputation_6h.append(cells)
intensity_in_nuclei = sorted(find_all_files (path, "concatenated_intensity_in_nuclei.npy"))
Amputation_6h_intensity = []
for i in range(len(intensity_in_nuclei)):
    
    cells = np.load(intensity_in_nuclei[i])
    cells = cells[cells > 0]
    Amputation_6h_intensity.append(cells)
# Out:
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Amputation/Image1/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Amputation/Image2/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Amputation/Image3/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Amputation/Image1/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Amputation/Image2/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Amputation/Image3/565/results/concatenated_intensity_in_nuclei.npy

# %%
path = "/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Incision"
spot_in_nuclei = sorted(find_all_files (path, "concatenated_spot_in_nuclei.npy"))
Incision_6h = []
for i in range(len(spot_in_nuclei)):
    
    cells = np.load(spot_in_nuclei[i])
    cells = cells[cells > 0]
    Incision_6h.append(cells)
intensity_in_nuclei = sorted(find_all_files (path, "concatenated_intensity_in_nuclei.npy"))
Incision_6h_intensity = []
for i in range(len(intensity_in_nuclei)):
    
    cells = np.load(intensity_in_nuclei[i])
    cells = cells[cells > 0]
    Incision_6h_intensity.append(cells)
# Out:
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Incision/Image1/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Incision/Image2/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Incision/Image3/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Incision/Image1/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Incision/Image2/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/6hr_Incision/Image3/565/results/concatenated_intensity_in_nuclei.npy

# %%
path = "/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Amputation/"
spot_in_nuclei = sorted(find_all_files (path, "concatenated_spot_in_nuclei.npy"))
Amputation_12h = []
for i in range(len(spot_in_nuclei)):
    
    cells = np.load(spot_in_nuclei[i])
    cells = cells[cells > 0]
    Amputation_12h.append(cells)
intensity_in_nuclei = sorted(find_all_files (path, "concatenated_intensity_in_nuclei.npy"))
Amputation_12h_intensity = []
for i in range(len(intensity_in_nuclei)):
    
    cells = np.load(intensity_in_nuclei[i])
    cells = cells[cells > 0]
    Amputation_12h_intensity.append(cells)
# Out:
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Amputation/Image1/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Amputation/Image2/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Amputation/Image3/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Amputation/Image1/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Amputation/Image2/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Amputation/Image3/565/results/concatenated_intensity_in_nuclei.npy

# %%
path = "/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Incision"
spot_in_nuclei = sorted(find_all_files (path, "concatenated_spot_in_nuclei.npy"))
Incision_12h = []
for i in range(len(spot_in_nuclei)):
    
    cells = np.load(spot_in_nuclei[i])
    cells = cells[cells > 0]
    Incision_12h.append(cells)
intensity_in_nuclei = sorted(find_all_files (path, "concatenated_intensity_in_nuclei.npy"))
Incision_12h_intensity = []
for i in range(len(intensity_in_nuclei)):
    
    cells = np.load(intensity_in_nuclei[i])
    cells = cells[cells > 0]
    Incision_12h_intensity.append(cells)
# Out:
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Incision/Image1/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Incision/Image2/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Incision/Image3/565/results/concatenated_spot_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Incision/Image1/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Incision/Image2/565/results/concatenated_intensity_in_nuclei.npy
# /Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/12hr_Incision/Image3/565/results/concatenated_intensity_in_nuclei.npy

# %%
os.chdir("/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment")
data_dict = {
    "Incision_0h": Incision_0h_intensity,
    "Amputation_0h": Amputation_0h_intensity,
    "Incision_6h": Incision_6h_intensity,
    "Amputation_6h": Amputation_6h_intensity,
    "Incision_12h": Incision_12h_intensity,
    "Amputation_12h": Amputation_12h_intensity
}
import pandas as pd
# Create a dictionary to store columns
csv_data = {}

# Iterate over each condition and store separately
for key, arrays in data_dict.items():
    for i, arr in enumerate(arrays, start=1):
        csv_data[f"{key}_{i}"] = arr  # Unique column name

# Convert to DataFrame
df = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in csv_data.items()]))

# Save to CSV
df.to_csv("306_output_intensity.csv", index=False)

print("CSV file saved as output.csv!")
# Out:
# CSV file saved as output.csv!

# %%
os.chdir("/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment")
data_dict = {
    "Incision_0h": Incision_0h,
    "Amputation_0h": Amputation_0h,
    "Incision_6h": Incision_6h,
    "Amputation_6h": Amputation_6h,
    "Incision_12h": Incision_12h,
    "Amputation_12h": Amputation_12h
}

# Create a dictionary to store columns
csv_data = {}

# Iterate over each condition and store separately
for key, arrays in data_dict.items():
    for i, arr in enumerate(arrays, start=1):
        csv_data[f"{key}_{i}"] = arr  # Unique column name

# Convert to DataFrame
df = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in csv_data.items()]))

# Save to CSV
df.to_csv("306_output.csv", index=False)

print("CSV file saved as output.csv!")
# Out:
# CSV file saved as output.csv!

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
os.chdir("/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment")
# Read the CSV file
df = pd.read_csv("306_output.csv")

# Convert to long format for seaborn
df_long = df.melt(var_name="Condition", value_name="Value")

palette = {
    'Incision_0h_1': 'green',
    'Incision_0h_2': 'green',
    'Incision_0h_3': 'green',
    'Amputation_0h_1': 'blue',
    'Amputation_0h_2': 'blue',
    'Amputation_0h_3': 'blue',
    'Incision_6h_1': 'green',
    'Incision_6h_3': "green",
    'Incision_6h_2': "green",
    'Amputation_6h_1': 'blue',
    'Amputation_6h_2': 'blue',
    'Amputation_6h_3': 'blue',
    'Incision_12h_1': 'green',
    'Amputation_12h_1': 'blue',
    'Amputation_12h_2': 'blue',
    'Amputation_12h_3': 'blue',
    'Incision_12h_2': 'green',
    'Incision_12h_3': 'green',
    'Amputation_12h': 'blue', 
    'Amputation_6h' :'blue',
    'Incision_12h' :'green',
    'Incision_6h' :'green',
    'Incision_0h' :'blue',
    'Amputation_0h':'blue'
}
df_long['Group'] = df_long['Condition'].str.extract(r'([A-Za-z]+_\d+h)')[0]



plt.figure(figsize=(12, 6))

# Boxplot without grouping (keep individual conditions)
sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, palette=palette)

# Jittered points with transparency and custom colors for each condition
sns.stripplot(x="Condition", y="Value", data=df_long, jitter=0.3, size=2, alpha=0.4, 
              hue="Condition", palette=palette, dodge=False, marker="o")

# Custom X-axis labels (show broader group names)
labels = df_long['Condition'].unique()# Get unique group names
plt.xticks(ticks=range(len(df_long['Condition'].unique())), labels=labels, rotation=30)

# Adjustments
plt.title("Jittered Box Plot of wnt1 mRNA count in nuclei")
plt.ylabel("Count per cell")
plt.ylim(0,150)
plt.savefig("jittered_box_plot_of_mRNA_count_per_cell", dpi=300)
# Show the plot
plt.show()
# Out:
# /var/folders/s2/hm4xyqwd26xgwmf3znp5sffr0000gn/T/ipykernel_55008/1424252685.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, palette=palette)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
os.chdir("/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment")
# Read the CSV file
df = pd.read_csv("306_output.csv")

# Convert to long format for seaborn
df_long = df.melt(var_name="Condition", value_name="Value")

palette = {
    'Incision_0h_1': 'green',
    'Incision_0h_2': 'green',
    'Incision_0h_3': 'green',
    'Amputation_0h_1': 'blue',
    'Amputation_0h_2': 'blue',
    'Amputation_0h_3': 'blue',
    'Incision_6h_1': 'green',
    'Incision_6h_3': "green",
    'Incision_6h_2': "green",
    'Amputation_6h_1': 'blue',
    'Amputation_6h_2': 'blue',
    'Amputation_6h_3': 'blue',
    'Incision_12h_1': 'green',
    'Amputation_12h_1': 'blue',
    'Amputation_12h_2': 'blue',
    'Amputation_12h_3': 'blue',
    'Incision_12h_2': 'green',
    'Incision_12h_3': 'green',
    'Amputation_12h': 'blue', 
    'Amputation_6h' :'blue',
    'Incision_12h' :'green',
    'Incision_6h' :'green',
    'Incision_0h' :'blue',
    'Amputation_0h':'blue'
}
df_long['Group'] = df_long['Condition'].str.extract(r'([A-Za-z]+_\d+h)')[0]



plt.figure(figsize=(12, 6))

# Boxplot without grouping (keep individual conditions)
sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, palette=palette)

# Violin plot (distribution)
sns.violinplot(
    x="Condition",
    y="Value",
    data=df_long,
    palette=palette,
    hue=None,
    dodge=False,
    cut=0,
    inner=None
)
sns.stripplot(
    x="Condition",
    y="Value",
    data=df_long,
    jitter=0.3,
    size=2,
    alpha=0.2,
    color="k",  # or use `palette=palette` and `hue="Condition"` if you want colored dots
    dodge=False
)
# Custom X-axis labels (show broader group names)
labels = df_long['Condition'].unique()
plt.xticks(ticks=range(len(labels)), labels=labels, rotation=30)



# Adjustments
plt.title("Violin + Box Plot of wnt1 mRNA count in nuclei (log2 scale)")
plt.ylabel("mRNA expression per cell")
plt.savefig("violin_plot_of_mRNA_count_per_cell.png", dpi=300)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/s2/hm4xyqwd26xgwmf3znp5sffr0000gn/T/ipykernel_5767/2498775543.py:45: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, palette=palette)
# /var/folders/s2/hm4xyqwd26xgwmf3znp5sffr0000gn/T/ipykernel_5767/2498775543.py:48: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %%
from scipy.stats import ks_2samp
import pandas as pd

# KS test helper
def ks_test_by_condition(df, cond1, cond2):
    group1 = df[df["Condition"].str.startswith(cond1)]["Value"].dropna()
    group2 = df[df["Condition"].str.startswith(cond2)]["Value"].dropna()
    
    if len(group1) == 0 or len(group2) == 0:
        print(f"⚠️ One or both groups are empty: {cond1} vs {cond2}")
        return None
    
    stat, p_value = ks_2samp(group1, group2)
    print(f"{cond1} vs {cond2} --> KS stat: {stat:.4f}, p-value: {p_value:.4e}")
    return stat, p_value

# All desired comparisons
comparisons = [
    ("Incision_12h", "Amputation_12h"),
    ("Incision_0h", "Amputation_0h"),
    ("Amputation_12h", "Incision_6h"),
    ("Incision_12h", "Incision_6h"),
    ("Incision_6h", "Amputation_6h")  # New comparison
]

# Run and collect results
results = []
for cond1, cond2 in comparisons:
    result = ks_test_by_condition(df_long, cond1, cond2)
    if result:
        stat, pval = result
        results.append({
            "Comparison": f"{cond1} vs {cond2}",
            "KS_stat": stat,
            "p_value": pval
        })

# Convert to DataFrame and sort by p-value
results_df = pd.DataFrame(results).sort_values(by="p_value")
print("\n🧪 Sorted KS Test Results (by p-value):")
print(results_df.to_string(index=False))
results_df.to_csv("/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment/ks_test_results.csv", index=False)
# Out:
# Incision_12h vs Amputation_12h --> KS stat: 0.2201, p-value: 1.6879e-36
# Incision_0h vs Amputation_0h --> KS stat: 0.1433, p-value: 5.6399e-08
# Amputation_12h vs Incision_6h --> KS stat: 0.2119, p-value: 1.2551e-60
# Incision_12h vs Incision_6h --> KS stat: 0.0148, p-value: 9.9863e-01
# Incision_6h vs Amputation_6h --> KS stat: 0.0681, p-value: 1.2809e-06
#
# 🧪 Sorted KS Test Results (by p-value):
#                     Comparison  KS_stat      p_value
#  Amputation_12h vs Incision_6h 0.211894 1.255135e-60
# Incision_12h vs Amputation_12h 0.220100 1.687934e-36
#   Incision_0h vs Amputation_0h 0.143276 5.639877e-08
#   Incision_6h vs Amputation_6h 0.068122 1.280863e-06
#    Incision_12h vs Incision_6h 0.014782 9.986270e-01

# %%
from scipy.stats import mannwhitneyu
def mann_whitney_by_condition(df, cond1, cond2, alternative="two-sided"):
    group1 = df[df["Condition"].str.startswith(cond1)]["Value"].dropna()
    group2 = df[df["Condition"].str.startswith(cond2)]["Value"].dropna()
    
    if len(group1) == 0 or len(group2) == 0:
        print(f"⚠️ One or both groups are empty: {cond1} vs {cond2}")
        return None
    
    stat, p_value = mannwhitneyu(group1, group2, alternative=alternative)
    print(f"{cond1} vs {cond2} --> U stat: {stat:.4f}, p-value: {p_value:.4e}")
    return stat, p_value
comparisons = [
    ("Incision_12h", "Amputation_12h"),
    ("Incision_0h", "Amputation_0h"),
    ("Amputation_6h", "Amputation_12h"),
    ("Incision_6h", "Incision_12h"),
    ("Incision_6h", "Amputation_6h")  # Added one
]

# Store results
mw_results = []
for cond1, cond2 in comparisons:
    result = mann_whitney_by_condition(df_long, cond1, cond2, alternative="less")
    if result:
        stat, pval = result
        mw_results.append({
            "Comparison": f"{cond1} vs {cond2}",
            "U_stat": stat,
            "p_value": pval
        })

# Create DataFrame and sort
mw_results_df = pd.DataFrame(mw_results).sort_values(by="p_value")
print("\n📊 Mann–Whitney U Test Results (sorted by p-value):")
print(mw_results_df.to_string(index=False))
mw_results_df.to_csv("mann_whitney_results.csv", index=False)
# Out:
# Incision_12h vs Amputation_12h --> U stat: 2651448.5000, p-value: 4.1614e-43
# Incision_0h vs Amputation_0h --> U stat: 525388.5000, p-value: 4.1557e-10
# Amputation_6h vs Amputation_12h --> U stat: 23026279.5000, p-value: 5.7281e-99
# Incision_6h vs Incision_12h --> U stat: 913921.0000, p-value: 4.4922e-01
# Incision_6h vs Amputation_6h --> U stat: 6685251.5000, p-value: 1.0350e-08
#
# 📊 Mann–Whitney U Test Results (sorted by p-value):
#                      Comparison     U_stat      p_value
# Amputation_6h vs Amputation_12h 23026279.5 5.728065e-99
#  Incision_12h vs Amputation_12h  2651448.5 4.161413e-43
#    Incision_0h vs Amputation_0h   525388.5 4.155706e-10
#    Incision_6h vs Amputation_6h  6685251.5 1.035044e-08
#     Incision_6h vs Incision_12h   913921.0 4.492198e-01

# %%
import pandas as pd
from scipy import stats

# Load the Excel file
file_path = "/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/306_injury_site_length.xlsx"
df = pd.read_excel(file_path)

# Merge data for each time point
incision_0hr = np.concatenate(Incision_0h)
amputation_0hr = np.concatenate(Amputation_0h)

incision_6hr = np.concatenate(Incision_6h)
amputation_6hr = np.concatenate(Amputation_6h)

incision_12hr = np.concatenate(Incision_12h)
amputation_12hr = np.concatenate(Amputation_12h)

# Perform independent t-tests
t_stat_0hr, p_value_0hr = stats.ttest_ind(incision_0hr, amputation_0hr, equal_var=False)
t_stat_6hr, p_value_6hr = stats.ttest_ind(incision_6hr, amputation_6hr, equal_var=False)
t_stat_12hr, p_value_12hr = stats.ttest_ind(incision_12hr, amputation_12hr, equal_var=False)
t_stat_6to12hrin, p_value_6to12hrin = stats.ttest_ind(incision_6hr, incision_12hr, equal_var=False)
t_stat_6to12hram, p_value_6to12hram = stats.ttest_ind(amputation_6hr, amputation_12hr, equal_var=False)
alpha = 0.05
print("\nStatistical Significance:")
print("0hr:", "Significant difference" if p_value_0hr < alpha else "No significant difference")
print(p_value_0hr)
print("6hr:", "Significant difference" if p_value_6hr < alpha else "No significant difference")
print(p_value_6hr)
print("12hr:", "Significant difference" if p_value_12hr < alpha else "No significant difference")
print(p_value_12hr)
print("12hrto6hrin", "Significant difference" if p_value_6to12hrin < alpha else "No significant difference")
print(p_value_6to12hrin)
print("12hrto6hram", "Significant difference" if p_value_6to12hram < alpha else "No significant difference")
print(p_value_6to12hram)
# Out:
# Statistical Significance:
# 0hr: Significant difference
# 0.00010844222611171505
# 6hr: Significant difference
# 3.0449789673849205e-28
# 12hr: Significant difference
# 2.2674188235049763e-91
# 12hrto6hrin No significant difference
# 0.23742209362183858
# 12hrto6hram Significant difference
# 2.9278737588882275e-79

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
os.chdir("/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment")
# Read the CSV file
df = pd.read_csv("306_output_intensity.csv")

# Convert to long format for seaborn
df_long = df.melt(var_name="Condition", value_name="Value")

palette = {
    'Incision_0h_1': 'green',
    'Incision_0h_2': 'green',
    'Incision_0h_3': 'green',
    'Amputation_0h_1': 'blue',
    'Amputation_0h_2': 'blue',
    'Amputation_0h_3': 'blue',
    'Incision_6h_1': 'green',
    'Incision_6h_3': "green",
    'Incision_6h_2': "green",
    'Amputation_6h_1': 'blue',
    'Amputation_6h_2': 'blue',
    'Amputation_6h_3': 'blue',
    'Incision_12h_1': 'green',
    'Amputation_12h_1': 'blue',
    'Amputation_12h_2': 'blue',
    'Amputation_12h_3': 'blue',
    'Incision_12h_2': 'green',
    'Incision_12h_3': 'green',
    'Amputation_12h': 'blue', 
    'Amputation_6h' :'blue',
    'Incision_12h' :'green',
    'Incision_6h' :'green',
    'Incision_0h' :'blue',
    'Amputation_0h':'blue'
}
df_long['Group'] = df_long['Condition'].str.extract(r'([A-Za-z]+_\d+h)')[0]



plt.figure(figsize=(12, 6))

# Boxplot without grouping (keep individual conditions)
sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, palette=palette)

# Jittered points with transparency and custom colors for each condition
sns.stripplot(x="Condition", y="Value", data=df_long, jitter=0.3, size=2, alpha=0.4, 
              hue="Condition", palette=palette, dodge=False, marker="o")

# Custom X-axis labels (show broader group names)
labels = df_long['Condition'].unique()# Get unique group names
plt.xticks(ticks=range(len(df_long['Condition'].unique())), labels=labels, rotation=45)

# Adjustments
plt.title("Jittered Box Plot of wnt1 mRNA intensity in nuclei")
plt.ylabel("Intensity(A.U). per nuclei")
plt.savefig("violin_boxplot_of_mRNA_intensity_per_cell.png", dpi=300)
# Show the plot
plt.show()
# Out:
# /var/folders/s2/hm4xyqwd26xgwmf3znp5sffr0000gn/T/ipykernel_55008/3511670922.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, palette=palette)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Set working directory
os.chdir("/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/Experiment")

# Read the CSV file
df = pd.read_csv("306_output_intensity.csv")

# Convert to long format for seaborn
df_long = df.melt(var_name="Condition", value_name="Value")

# Color palette
palette = {
    'Incision_0h_1': 'green',
    'Incision_0h_2': 'green',
    'Incision_0h_3': 'green',
    'Amputation_0h_1': 'blue',
    'Amputation_0h_2': 'blue',
    'Amputation_0h_3': 'blue',
    'Incision_6h_1': 'green',
    'Incision_6h_2': 'green',
    'Incision_6h_3': 'green',
    'Amputation_6h_1': 'blue',
    'Amputation_6h_2': 'blue',
    'Amputation_6h_3': 'blue',
    'Incision_12h_1': 'green',
    'Incision_12h_2': 'green',
    'Incision_12h_3': 'green',
    'Amputation_12h_1': 'blue',
    'Amputation_12h_2': 'blue',
    'Amputation_12h_3': 'blue',
    'Amputation_12h': 'blue',
    'Amputation_6h': 'blue',
    'Incision_12h': 'green',
    'Incision_6h': 'green',
    'Incision_0h': 'blue',
    'Amputation_0h': 'blue'
}

# Extract group info
df_long['Group'] = df_long['Condition'].str.extract(r'([A-Za-z]+_\d+h)')[0]

# Plot setup
plt.figure(figsize=(14, 6))

# Violin plot (smoothed distribution)
sns.violinplot(x="Condition", y="Value", data=df_long, palette=palette,
               inner=None, cut=0)

# Boxplot on top
sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False, 
            palette=palette, linewidth=1, width=0.3)

# Jittered individual data points
sns.stripplot(x="Condition", y="Value", data=df_long, jitter=0.3, size=2, 
              alpha=0.4, hue="Condition", palette=palette, dodge=False, marker="o")

# X-axis labels
labels = df_long['Condition'].unique()
plt.xticks(ticks=range(len(labels)), labels=labels, rotation=45)

# Log10 Y-axis scale
plt.yscale("log", base=10)
plt.ylabel("Log10(Intensity [A.U.] per nucleus)")

# Title and layout
plt.title("Violin + Box Plot of wnt1 mRNA intensity in nuclei (log10 scale)")
plt.tight_layout()

# Save the figure
plt.savefig("violin_boxplot_of_mRNA_intensity_per_cell_log10.png", dpi=300)

# Show the plot
plt.show()
# Out:
# /var/folders/s2/hm4xyqwd26xgwmf3znp5sffr0000gn/T/ipykernel_55008/3188417972.py:50: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Condition", y="Value", data=df_long, palette=palette,
# /var/folders/s2/hm4xyqwd26xgwmf3znp5sffr0000gn/T/ipykernel_55008/3188417972.py:54: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Condition", y="Value", data=df_long, showfliers=False,

# %%
df_long = df.melt(var_name="Condition", value_name="Value")
df_long['Group'] = df_long['Condition'].str.extract(r'([A-Za-z]+_\d+h)')[0]
from scipy.stats import ks_2samp, mannwhitneyu

def ks_test_by_condition(df, cond1, cond2):
    group1 = df[df["Condition"].str.startswith(cond1)]["Value"].dropna()
    group2 = df[df["Condition"].str.startswith(cond2)]["Value"].dropna()
    if group1.empty or group2.empty:
        print(f"⚠️ Empty group for KS: {cond1} vs {cond2}")
        return None
    stat, p_value = ks_2samp(group1, group2)
    print(f"KS: {cond1} vs {cond2} → stat: {stat:.4f}, p: {p_value:.4e}")
    return {"Comparison": f"{cond1} vs {cond2}", "KS_stat": stat, "p_value": p_value}

def mann_whitney_by_condition(df, cond1, cond2, alternative="two-sided"):
    group1 = df[df["Condition"].str.startswith(cond1)]["Value"].dropna()
    group2 = df[df["Condition"].str.startswith(cond2)]["Value"].dropna()
    if group1.empty or group2.empty:
        print(f"⚠️ Empty group for MW: {cond1} vs {cond2}")
        return None
    stat, p_value = mannwhitneyu(group1, group2, alternative=alternative)
    print(f"MWU ({alternative}): {cond1} vs {cond2} → U: {stat:.4f}, p: {p_value:.4e}")
    return {"Comparison": f"{cond1} vs {cond2}", "U_stat": stat, "p_value": p_value}
comparisons = [
    ("Incision_12h", "Amputation_12h"),
    ("Incision_0h", "Amputation_0h"),
    ("Amputation_6h", "Amputation_12h"),
    ("Incision_6h", "Incision_12h"),
    ("Incision_6h", "Amputation_6h")]  # Added one

# Collect results
ks_results = []
mw_results = []

for c1, c2 in comparisons:
    ks = ks_test_by_condition(df_long, c1, c2)
    mw = mann_whitney_by_condition(df_long, c1, c2, alternative="two-sided")
    if ks: ks_results.append(ks)
    if mw: mw_results.append(mw)

# Convert to DataFrames
ks_df = pd.DataFrame(ks_results).sort_values("p_value")
mw_df = pd.DataFrame(mw_results).sort_values("p_value")

# Save results
ks_df.to_csv("ks_test_results_on_intensity.csv", index=False)
mw_df.to_csv("mannwhitneyu_results_on_intensity.csv", index=False)
# Out:
# KS: Incision_12h vs Amputation_12h → stat: 0.2137, p: 2.0730e-34
# MWU (two-sided): Incision_12h vs Amputation_12h → U: 2604134.5000, p: 9.2092e-44
# KS: Incision_0h vs Amputation_0h → stat: 0.1794, p: 2.8048e-12
# MWU (two-sided): Incision_0h vs Amputation_0h → U: 475175.5000, p: 9.0402e-16
# KS: Amputation_6h vs Amputation_12h → stat: 0.1055, p: 6.1019e-37
# MWU (two-sided): Amputation_6h vs Amputation_12h → U: 25838165.5000, p: 2.7954e-21
# KS: Incision_6h vs Incision_12h → stat: 0.1133, p: 1.3758e-07
# MWU (two-sided): Incision_6h vs Incision_12h → U: 778406.5000, p: 4.6474e-11
# KS: Incision_6h vs Amputation_6h → stat: 0.2350, p: 1.1403e-74
# MWU (two-sided): Incision_6h vs Amputation_6h → U: 4749816.0000, p: 9.8722e-120

# %%
import pandas as pd
os.chdir("/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter")
# Load the Excel file
file_path = "/Volumes/Backup Plus/Experiment_results/306_analysis_results_alter/306_injury_site_length.xlsx"
df = pd.read_excel(file_path)

# Display the dataframe
print(df)
# Out:
#   Unnamed: 0  0h_Amputation  0h_Incision  6h_Amputation  6h_Incision  \
# 0     Image1        374.539      223.801        592.340      273.616
# 1     Image2        348.630      291.867        508.091      283.930
# 2     Image3        469.485      210.422        520.016      366.820
#
#    12h_Amputation  12h_Incision
# 0         392.204       191.661
# 1         408.729       224.196
# 2         557.390       176.317

# %%
def compute_sums(data_arrays, first_value):
    return [arr.sum() / first_value for arr in data_arrays]

# Function to compute lengths divided by first number in dataframe
def compute_lengths(data_arrays, first_value):
    return [len(arr) / first_value for arr in data_arrays]

# Create new DataFrames
sum_df = pd.DataFrame({
    "Incision_0h": compute_sums(Incision_0h, df["0h_Incision"][0]),
    "Amputation_0h": compute_sums(Amputation_0h, df["0h_Amputation"][0]),
    "Incision_6h": compute_sums(Incision_6h, df["6h_Incision"][0]),
    "Amputation_6h": compute_sums(Amputation_6h, df["6h_Amputation"][0]),
    "Incision_12h": compute_sums(Incision_12h, df["12h_Incision"][0]),
    "Amputation_12h": compute_sums(Amputation_12h, df["12h_Amputation"][0])
})

length_df = pd.DataFrame({
    "Incision_0h": compute_lengths(Incision_0h, df["0h_Incision"][0]),
    "Amputation_0h": compute_lengths(Amputation_0h, df["0h_Amputation"][0]),
    "Incision_6h": compute_lengths(Incision_6h, df["6h_Incision"][0]),
    "Amputation_6h": compute_lengths(Amputation_6h, df["6h_Amputation"][0]),
    "Incision_12h": compute_lengths(Incision_12h, df["12h_Incision"][0]),
    "Amputation_12h": compute_lengths(Amputation_12h, df["12h_Amputation"][0])
})

# Display results
print("Average spot count per injury site length DataFrame:")
print(sum_df)
sum_df.to_csv("306_output_spot_count_per_injuyr_site_length.csv", index=False)

print("CSV file saved as output.csv!")
print("\nAverage cell expressing per injury site length:")
print(length_df)
length_df.to_csv("306_output_Cell_expressing_per_injury_length.csv", index=False)

print("CSV file saved as output.csv!")
# Out:
# Average spot count per injury site length DataFrame:
#    Incision_0h  Amputation_0h  Incision_6h  Amputation_6h  Incision_12h  \
# 0     1.175151       1.129388     9.133238      20.484857      4.132296
# 1     0.102770      10.455520     1.589819      11.743256      8.953308
# 2     2.126890       0.192236     8.161072      19.573218      1.398302
#
#    Amputation_12h
# 0       40.744103
# 1       36.001673
# 2       76.151697
# CSV file saved as output.csv!
#
# Average cell expressing per injury site length:
#    Incision_0h  Amputation_0h  Incision_6h  Amputation_6h  Incision_12h  \
# 0     0.875778       0.587389     3.165020       4.315089      1.429607
# 1     0.080429       5.817819     0.884451       3.256576      2.749647
# 2     1.309199       0.066749     2.964008       5.157511      0.803502
#
#    Amputation_12h
# 0        6.047873
# 1        4.688886
# 2        8.447135
# CSV file saved as output.csv!

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Melt the data
sum_melted = sum_df.melt(var_name='Condition', value_name='Average Spot Count per Length')
length_melted = length_df.melt(var_name='Condition', value_name='Average Cell Count per Length')

# Plot for sum_df with points overlaid
plt.figure(figsize=(10, 6))
sns.boxplot(x='Condition', y='Average Spot Count per Length', data=sum_melted,
            color='lightgray', showcaps=True, boxprops={'facecolor':'lightgray'},
            showfliers=False, whiskerprops={'color':'black'}, medianprops={'color':'black'})
sns.stripplot(x='Condition', y='Average Spot Count per Length', data=sum_melted,
              color='black', size=4, jitter=True, alpha=0.7)
plt.title('Boxplot with Data Points: Average Spot Count per Injury Site Length')
plt.tight_layout()
plt.savefig("Boxplot with Data Points: Average Spot Count per Injury Site Length.png", dpi=300)
plt.show()

# Plot for length_df with points overlaid
plt.figure(figsize=(10, 6))
sns.boxplot(x='Condition', y='Average Cell Count per Length', data=length_melted,
            color='lightgray', showcaps=True, boxprops={'facecolor':'lightgray'},
            showfliers=False, whiskerprops={'color':'black'}, medianprops={'color':'black'})
sns.stripplot(x='Condition', y='Average Cell Count per Length', data=length_melted,
              color='black', size=4, jitter=True, alpha=0.7)
plt.title('Boxplot with Data Points: Average Cell Count per Injury Site Length')
plt.tight_layout()
plt.savefig("Boxplot with Data Points: Average Cell Count per Injury Site Length.png", dpi=300)
plt.show()
